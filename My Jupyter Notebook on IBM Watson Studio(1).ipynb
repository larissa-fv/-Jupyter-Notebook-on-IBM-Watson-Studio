# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio #

# %% [markdown]
# **Larissa Ferreira**

# %% [markdown]
# I work whit IT Support

# %% [markdown]
# *I am interested in data science because i like data a solvethe problems*

# %% [markdown]
# ### The Code ###

# %%
def gausses (n):
    return(n*(n+1))/2

gausses (100) == sum
# Out:
# False

# %% [markdown]
# * One
# * Dois

# %% [markdown]
# https://www.ibm.com/br-pt

# %% [markdown]
#  **End**
